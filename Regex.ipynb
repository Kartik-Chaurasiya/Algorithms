# %% [markdown]
# <a href="https://colab.research.google.com/github/Syntax-code/Algorithms/blob/master/Regex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ( ) indicate what we want from the desired searched pattern
#
# ex..
#
# r"\[(\w+)\]"
#
# finds patterns like [pdf], [asdf]
#
# but returns pdf, asdf

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# flags = re.I
#
# Searches for all python, Python, pYthon, blah

# %%
pattern = r"python"
python_counts = titles.str.contains(pattern, flags=re.I).sum()
print(python_counts)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <h3>Example
#
# Match instances of C or c where they are not preceded or followed by another word character.
#
# From the match above:
#
# Exclude instances where it is followed by a . or + character, without removing instances where the match occurs at the end of the string.
#
# Exclude instances where the word 'Series' immediately precedes the match.

# %%
pattern = r"(?<!Series\s)\b[Cc]\b(?![\+\.])"
c_mentions = titles.str.contains(pattern).sum()

# %%
import re
test_cases = [
              "I'm going to read a book.",
              "Green is my favorite color.",
              "My name is Aaron.",
              "No doubles here.",
              "I have a pet eel."
             ]

for tc in test_cases:
    print(re.search(r"(\w)\1", tc))
# Out:
# <_sre.SRE_Match object; span=(21, 23), match='oo'>
# <_sre.SRE_Match object; span=(2, 4), match='ee'>
# None
# None
# <_sre.SRE_Match object; span=(13, 15), match='ee'>

# %%
re.sub(pattern, repl, string, flags=0)

Series.str.replace(pat, repl, flags=0)                                  // repl -----> replace with

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ?P<name'>                  // name of the column
